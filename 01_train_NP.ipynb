# %%
import sys
sys.path.append('./src/')

from data_utils import get_dataframe
from train_utils import run_optuna_tuning_NP

DATABASE_URL = '...'

# %%
df_m4 = get_dataframe('M4')

# %%
run_optuna_tuning_NP(df_m4, DATABASE_URL, 'VP-M4-kalvin-kelenfold-ST-NP', n_trials=50, n_jobs=1)
